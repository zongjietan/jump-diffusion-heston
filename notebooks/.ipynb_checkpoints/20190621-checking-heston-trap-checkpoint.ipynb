# %% [markdown]
# # NEED TO MANIPULATE OWN CF UNTIL STABLE. THEN WILL KNOW HOW TO MANIPULATE OTHER

# %%
import os
os.chdir(r'/Users/ryanmccrickerd/desktop/jdheston')

# %%
import numpy as np
import pandas as pd
from jdheston import jdheston as jdh
from jdheston import config as cfg
from matplotlib import pyplot as plt
from scipy.stats import norm
# import mpl
# %matplotlib inline

# %%
nx = np.newaxis
cfg.config(scale=1.5,print_keys=False)

# %%
σ,ρ,v,κ = 0.1,-0.7,1,1.
α,β,γ,v0,ρ = σ*v,κ,σ**2,σ**2,ρ
θ = α,β,γ,v0,ρ

# %%
T = np.array([1/52,1/12,3/12,6/12,9/12,1])[:,nx]
M = ['1W','1M','3M','6M','9M','1Y']
Δ = np.linspace(5,95,19)[nx,:]/100
k = norm.ppf(Δ)*σ*np.sqrt(T)

# %%
pd.DataFrame(k,index=M,columns=Δ[0,:])
# Out:
#         0.05      0.10      0.15      0.20      0.25      0.30      0.35  \
# 1W -0.022810 -0.017772 -0.014373 -0.011671 -0.009353 -0.007272 -0.005343
# 1M -0.047483 -0.036995 -0.029919 -0.024296 -0.019471 -0.015138 -0.011123
# 3M -0.082243 -0.064078 -0.051822 -0.042081 -0.033724 -0.026220 -0.019266
# 6M -0.116309 -0.090619 -0.073287 -0.059512 -0.047694 -0.037081 -0.027246
# 9M -0.142449 -0.110986 -0.089758 -0.072887 -0.058413 -0.045414 -0.033370
# 1Y -0.164485 -0.128155 -0.103643 -0.084162 -0.067449 -0.052440 -0.038532
#
#         0.40      0.45  0.50      0.55      0.60      0.65      0.70  \
# 1W -0.003513 -0.001743   0.0  0.001743  0.003513  0.005343  0.007272
# 1M -0.007314 -0.003628   0.0  0.003628  0.007314  0.011123  0.015138
# 3M -0.012667 -0.006283   0.0  0.006283  0.012667  0.019266  0.026220
# 6M -0.017914 -0.008886   0.0  0.008886  0.017914  0.027246  0.037081
# 9M -0.021941 -0.010883   0.0  0.010883  0.021941  0.033370  0.045414
# 1Y -0.025335 -0.012566   0.0  0.012566  0.025335  0.038532  0.052440
#
#         0.75      0.80      0.85      0.90      0.95
# 1W  0.009353  0.011671  0.014373  0.017772  0.022810
# 1M  0.019471  0.024296  0.029919  0.036995  0.047483
# 3M  0.033724  0.042081  0.051822  0.064078  0.082243
# 6M  0.047694  0.059512  0.073287  0.090619  0.116309
# 9M  0.058413  0.072887  0.089758  0.110986  0.142449
# 1Y  0.067449  0.084162  0.103643  0.128155  0.164485

# %%
C = jdh.pricer(T,k,θ)

# %%
BSV = jdh.surface(T,k,C)

# %%
pd.DataFrame(BSV,index=M,columns=Δ[0,:])
# Out:
#         0.05      0.10      0.15      0.20      0.25      0.30      0.35  \
# 1W  0.103830  0.102976  0.102396  0.101932  0.101534  0.101175  0.100841
# 1M  0.107518  0.105825  0.104667  0.103738  0.102934  0.102208  0.101531
# 3M  0.111745  0.109064  0.107211  0.105713  0.104410  0.103227  0.102119
# 6M  0.114740  0.111314  0.108932  0.106996  0.105306  0.103765  0.102319
# 9M  0.116313  0.112460  0.109773  0.107585  0.105672  0.103926  0.102285
# 1Y  0.117206  0.113081  0.110203  0.107859  0.105808  0.103936  0.102177
#
#         0.40      0.45      0.50      0.55      0.60      0.65      0.70  \
# 1W  0.100524  0.100217  0.099914  0.099610  0.099301  0.098981  0.098643
# 1M  0.100885  0.100258  0.099638  0.099015  0.098381  0.097722  0.097027
# 3M  0.101058  0.100024  0.098999  0.097967  0.096914  0.095821  0.094667
# 6M  0.100930  0.099573  0.098226  0.096869  0.095484  0.094048  0.092537
# 9M  0.100709  0.099168  0.097638  0.096099  0.094529  0.092906  0.091205
# 1Y  0.100487  0.098837  0.097200  0.095555  0.093880  0.092153  0.090348
#
#         0.75      0.80      0.85      0.90      0.95
# 1W  0.098277  0.097870  0.097394  0.096794  0.095904
# 1M  0.096275  0.095436  0.094458  0.093231  0.091426
# 3M  0.093422  0.092040  0.090446  0.088486  0.085741
# 6M  0.090917  0.089139  0.087128  0.084743  0.081653
# 9M  0.089391  0.087421  0.085225  0.082690  0.079570
# 1Y  0.088433  0.086365  0.084083  0.081486  0.078375

# %%
plot,axes = plt.subplots()
for i in range(len(T[:,0])):
    axes.plot(k[i,:],100*BSV[i,:])
    axes.set_xlabel(r'$k$')
    axes.set_ylabel(r'$\bar{\sigma}(k,\tau)$')
